# %% [markdown]
# ## Mortality in Moscow 2010-2020
#
# TODO: Add introduction
# [Dataset](https://www.kaggle.com/vitaliymalcev/mortaliy-moscow-20102020)

# %%
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(12,8)})

# %% [markdown]
# ### Features
#
# TODO: Add features' description

# %%
df = pd.read_csv('data/moscow_stats.csv')

# %%
df.set_index('ID', inplace=True)

# %%
df.head()
# Out:
#     Year     Month  StateRegistrationOfBirth  \
# ID
# 1   2010   January                      9206
# 2   2010  February                      9060
# 3   2010     March                     10934
# 4   2010     April                     10140
# 5   2010       May                      9457
#
#     NumberOfBirthCertificatesForBoys  NumberOfBirthCertificatesForGirls  \
# ID
# 1                               4785                               4421
# 2                               4656                               4404
# 3                               5630                               5304
# 4                               5278                               4862
# 5                               4825                               4632
#
#     StateRegistrationOfDeath  StateRegistrationOfMarriage  \
# ID
# 1                      10430                         4997
# 2                       9573                         4873
# 3                      10528                         3642
# ...

# %%
df[['NumberOfBirthCertificatesForBoys', 'NumberOfBirthCertificatesForGirls']].describe()
# Out:
#        NumberOfBirthCertificatesForBoys  NumberOfBirthCertificatesForGirls
# count                        124.000000                         124.000000
# mean                        5765.685484                        5411.354839
# std                          626.414424                         582.151814
# min                         2042.000000                        1917.000000
# 25%                         5458.000000                        5119.250000
# 50%                         5820.500000                        5430.500000
# 75%                         6115.250000                        5748.750000
# max                         7082.000000                        6646.000000

# %% [markdown]
# ### How total population has changed over years?

# %%
sns.lineplot(x='Year', y='TotalPopulationThisYear', data=df);

# %%
sns.countplot(x='StateRegistrationOfBirth', hue='Month', data=df);
