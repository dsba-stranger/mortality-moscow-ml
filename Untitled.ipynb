# %% [markdown]
# ## Mortality in Moscow 2010-2020
#
# TODO: Add introduction
# [Dataset](https://www.kaggle.com/vitaliymalcev/mortaliy-moscow-20102020)

# %%
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Features
#
# TODO: Add features' description

# %%
df = pd.read_csv('data/moscow_stats.csv')

# %%
df.set_index('ID', inplace=True)

# %%
df.head()
# Out:
#     Year     Month  StateRegistrationOfBirth  \
# ID
# 1   2010   January                      9206
# 2   2010  February                      9060
# 3   2010     March                     10934
# 4   2010     April                     10140
# 5   2010       May                      9457
#
#     NumberOfBirthCertificatesForBoys  NumberOfBirthCertificatesForGirls  \
# ID
# 1                               4785                               4421
# 2                               4656                               4404
# 3                               5630                               5304
# 4                               5278                               4862
# 5                               4825                               4632
#
#     StateRegistrationOfDeath  StateRegistrationOfMarriage  \
# ID
# 1                      10430                         4997
# 2                       9573                         4873
# 3                      10528                         3642
# ...

# %%
df_months = df.groupby(['Month']).sum()

# %%
df_months['StateRegistrationOfMarriage']
# Out:
# Month
# April         75300
# August       121842
# December      64771
# February      58157
# January       46926
# July         114920
# June         103884
# March         55383
# May           45822
# November      63229
# October       79080
# September    109377
# Name: StateRegistrationOfMarriage, dtype: int64

# %%
sns.set(rc={'figure.figsize':(12,8)})
sns.lineplot(x='Year', y='StateRegistrationOfBirth', hue='Month', data=df);
